# %% [markdown]
# <a href="https://colab.research.google.com/github/SeungHwaJung/0623_github_test/blob/main/0625_python_define_%26_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# define

# %%
# 함수 정의
def greet():
    print("안녕하세요!")

def add(a, b):
    return a + b

def is_even(n):
    return n % 2 == 0

def square(n):
    return n ** 2

def say_name(name):
    return f"제 이름은 {name}입니다."

# %% [markdown]
# class

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def say_hello(self):
        print(f"안녕! 나는 {self.name}이야.")

class Animal:
    def __init__(self, kind):
        self.kind = kind

    def sound(self):
        print(f"{self.kind} 소리가 납니다.")

class Calculator:
    def add(self, a, b):
        return a + b

class Student:
    def __init__(self, name, grade):
        self.name = name
        self.grade = grade

    def info(self):
        return f"{self.name}의 성적은 {self.grade}"

class Car:
    def __init__(self, brand):
        self.brand = brand

    def drive(self):
        print(f"{self.brand} 자동차가 출발합니다!")

class Calculator:
    def add(self, a, b):
        return a + b

    def sub(self, a, b):
        return a - b

# %% [markdown]
# 자율주행관련

# %%
class Car:
    def __init__(self, brand):
        self.brand = brand
        self.speed = 0
        self.running = False

    def drive(self):
        self.running = True
        print(f"{self.brand} 자동차가 주행을 시작합니다.")

    def stop(self):
        self.running = False
        self.speed = 0
        print(f"{self.brand} 자동차가 멈췄습니다.")

    def accelerate(self, value):
        self.speed += value
        print(f"{self.brand} 자동차 속도가 {self.speed}km/h로 증가했습니다.")

    def decelerate(self, value):
        self.speed -= value
        if self.speed < 0:
            self.speed = 0
        print(f"{self.brand} 자동차 속도가 {self.speed}km/h로 감소했습니다.")

# %% [markdown]
# # 새 섹션
